# %%
print ("Hello World")
a = input("What is your name");
print("Your name is",a);
Var1 = float(input("Give me the first number"))
Var2 = float(input("Give me the second number"))
print("The 2 number multiplied together are:",Var1*Var2)
if Var1 > Var2:
    print ("The first num",Var1,"is greater than the second",Var2)
elif Var2 > Var1:
    print ("The second num",Var2,"is greater than",Var1)
else:
    print ("The Values given are equal")
# Out:
# Hello World
# Your name is ARran
# The 2 number multiplied together are: 1000.0
# The first num 100.0 is greater than the second 10.0

# %%
Calcfunc = int(input('What function would you like? 1.Addition 2.Subtraction 3.Division 4.Multiplication'))
var1 = float(input("First NUmber"))
var2 = float(input("What is the second number"))
if Calcfunc == 1:
    print ("The result is: ",var1+var2)
elif Calcfunc ==2:
    print ("The Result is: ",var1-var2)
elif Calcfunc ==3:
    print("The Result is: ",var1/var2)
elif Calcfunc == 4:
    print("The Result is: ",var1*var2)
# Out:
# The Result is:  5.0

# %%
Age = int(input("how old are you?"))
if Age <= 5:
    print("A Child 5 or younger is free")
elif Age>5 and Age<=12:
    print("For a Kid of age:" ,Age, "a ticket is $5")
elif Age>12 and Age<=17:
    print(" For a Teen of age:",Age, "a ticket is $8")
elif Age>17 and Age<=59:
    print(" For an adult of age:" ,Age, "a ticket is $12")
elif Age>59:
    print(" For a senior of age:" ,Age, "a ticket is Free")
# Out:
#  For a Teen of age: 17 a ticket is $8
